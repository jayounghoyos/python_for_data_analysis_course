# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open("archivo.txt","r", encoding="utf-8")

# %%
print("Directorio de trabajo actual:")
# !pwd
# Out:
# Directorio de trabajo actial:
# /home/juanandresyounghoyos/Documents/python_for_data_analysis_course
